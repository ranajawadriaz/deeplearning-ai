# %% [markdown]
# # L9: Building LLM prompts with variables

# %% [markdown]
# In the next cell, you will import the function `print_llm_response` that uses an LLM with an instruction that you provide as a string and displays the result.

# %%
from helper_functions import print_llm_response

# %% [markdown]
# Basically, you can use that function as if you were asking a chatbot. You just need to provide your instructions as a string. For instance, you can ask "What is the capital of France?" using the following code:

# %%
print_llm_response("What is the capital of France?")
# Out:
# The capital of France is **Paris**.

# %% [markdown]
# Let's ask the LLM for the lifestyle description for Otto Matic, whose name is stored in `name`, if he were a `dog_age` years old dog.

# %%
name = "Otto Matic"
dog_age = 21/7

# %%
print_llm_response(f"""If {name} were a dog, he would be {dog_age} years old.
Describe what life stage that would be for a dog and what that might 
entail in terms of energy level, interests, and behavior.""")
# Out:
# If Otto Matic were a 3.0-year-old dog, he would be right in the prime of his **young adulthood** or **early adulthood** phase. This is often considered the peak of a dog's physical and mental capabilities, having left the puppy shenanigans behind but still years away from senior slowing down.
#
# Here's what that might entail:
#
# *   **Life Stage: Young Adult / Prime Adulthood**
#     This stage is comparable to a human in their early to mid-20s – fully grown, physically mature, and mentally sharp, but still with a zest for life and plenty of energy. Their personality is well-established, and they've generally settled into their adult size and demeanor.
#
# *   **Energy Level:**
#     Expect a **high and sustained energy level**. While they may have outgrown the frantic, often unfocused bursts of puppy zoomies, a 3-year-old dog has incredible stamina. They are ready for long walks, runs, hikes, vigorous games of fetch, or structured playtime at a dog park. This energy isn't just physical; it's also mental – they're eager to engage and *do things*. They still need significant daily exercise (often 1-2 hours of vigorous activity, depending on the breed) to prevent boredom and potential destructive behaviors.
#
# *   **Interests:**
#     Their world is expanding, and their interests are broad:
#     *   **Socialization:** Other dogs, new people, and especially their human family. Playdates and dog park visits are often highly enjoyable.
#     *   **Exploration:** Scent work, long sniffy walks, exploring new environments. Their noses are powerful tools they love to use.
#     *   **Play:** Fetch, tug-of-war, chasing, puzzle toys that challenge them mentally. They often have a strong retrieve drive.
#     *   **Learning & Engagement:** This is a fantastic age for advanced training, dog sports (agility, flyball, obedience), or learning complex tricks. They thrive on mental stimulation and having a "job" to do.
#     *   **Comfort & Companionship:** After their exercise needs are met, they often enjoy cuddling, napping, and being close to their family.
#
# *   **Behavior:**
#     Behaviorally, a 3-year-old dog is typically:
#     *   **More Mature & Stable:** Their personality is well-established, and they are generally past the major chewing and house-training challenges of puppyhood (assuming appropriate training and environment).
#     *   **Highly Trainable:** They have excellent focus and the capacity to learn complex commands and routines. This is an ideal time for honing obedience skills or teaching new skills.
#     *   **Affectionate & Bonded:** They often form very strong bonds with their family, seeking attention, cuddles, and companionship after their exercise needs are met.
#     *   **Can be Destructive if Bored:** The flip side of their high energy and intelligence is that if their physical and mental needs aren't met, they can become bored, leading to undesirable behaviors like excessive barking, digging, chewing (even if they're "past" the puppy chewing stage, boredom can bring it back), or even anxiety. They need a consistent routine that includes both physical and mental stimulation.
#     *   **Developing Responsibility:** They might start taking on more "responsible" roles, like being more watchful of the house or younger family members.
#
# In essence, a 3-year-old Otto Matic would be a **vibrant, intelligent, and physically capable dog** – a joy to live with, but one who requires consistent engagement, plenty of exercise, and mental challenges to truly thrive and be their best self.

# %% [markdown]
# <b>You just used AI with your own variables!</b> You used an LLM with instructions that included variables you defined in this notebook.
#
# <b>Congratulations 🎉🎉🎉</b>

# %% [markdown]
# ## Variable names restrictions

# %% [markdown]
# The following variable names also have some problems. Try to fix them yourself or use the help from the chatbot.

# %%
driver = "unicorn"
drivers_vehicle = "colorful, asymmetric dinosaur car"
favorite_planet = "Pluto"

# %% [markdown]
# Now, update the next cell with any changes you made in the previous cell.

# %%
print_llm_response(f"""Write me a 300 word children's story about a {driver} racing
a {drivers_vehicle} for the {favorite_planet} champion cup.""")
# Out:
# Far, far away, on the frosty plains of Pluto, awaited the most exciting race in the galaxy: the Pluto Champion Cup! The grand prize shimmered under the distant sun: a trophy shaped like a tiny, glittering planet.
#
# Starlight, a magnificent unicorn with a rainbow-sparkle mane and a horn that twinkled like a distant star, nervously pawed the icy starting line. Her heart pounded with a mix of excitement and anticipation.
#
# Beside her, a truly spectacular machine rumbled. It was a car, but shaped like a chunky, friendly dinosaur! One side was neon green, the other bright purple, with big yellow polka dots. Its tail fin wiggled as it idled, and one of its headlamps was slightly bigger than the other, giving it a wonderfully lopsided, cheerful grin. This was Dino-Zoomer, and a tiny, green alien waved from its cockpit.
#
# A little orange alien in a sparkly uniform raised a checkered flag. "Racers, to your marks! Ready, set, GO!"
#
# Starlight burst forward, her hooves kicking up crystalline ice dust. She felt the swift, cold breeze (or lack thereof, in space!) in her magnificent mane. Dino-Zoomer roared, its lopsided wheels spinning, surprisingly fast! They zipped past towering ice mountains and shimmering diamond craters, neck and neck.
#
# Starlight used her magic, gliding gracefully over a tricky patch of asteroid debris. Dino-Zoomer, with a puff of colorful smoke, zoomed *under* a low-hanging ice arch, its driver giggling inside. The finish line, a shimmering rainbow arch, was just ahead! Starlight poured every ounce of unicorn magic into her gallop. Dino-Zoomer let out a mighty, joyful *ROAR*, its engines glowing bright.
#
# WHOOSH! They crossed the line in a brilliant flash of light! The crowd of friendly aliens and space-creatures gasped. "It's a photo finish!" cried the announcer. "And... it's a TIE! Co-champions!"
#
# Starlight trotted over, nudging Dino-Zoomer with her soft nose. The car's side door popped open, and the little blue alien beamed. They had both tried their very best, and that made them both winners. The Pluto Champion Cup looked even better with two sets of hoofprints and tire tracks on it!

# %% [markdown]
# ## Extra practice
#
# Try the exercises below to practice the concepts from this lesson. Read the comments in each cell with the instructions for each exercise.
#
# <b>Feel free to use the chatbot if you need help.</b>

# %%
# Fix this code
favorite_book = "1001 Ways to Wear a Hat"
second_fav_book="2002 Ways to Wear a Scarf"
print(f"My most favorite book is {favorite_book}, but I also like {second_fav_book}")
# Out:
# My most favorite book is 1001 Ways to Wear a Hat, but I also like 2002 Ways to Wear a Scarf

# %%
# Make variables for your favorite game, movie, and food.
# Then use print_llm_response to ask the LLM to recommend you
# a new song to listen to based on your likes.
game='need for speed'
movie='midsommar'
food='large shawarma'
print_llm_response(f"""
recommend me a new song to listen based on my likings:
game={game},
movie={movie},
food={food}

keep the response short

""")
# Out:
# **Rezz - Psycho (feat. Fknsyd)**
#
# It's got the driving electronic energy for NFS, the dark, hypnotic, and slightly unsettling vibe for Midsommar, and a rich, deep sound like a satisfying shawarma.
